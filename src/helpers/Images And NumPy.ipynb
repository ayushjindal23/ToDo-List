# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('C:/Users/Ayush/Desktop/CV with python/New folder/puppy.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x321 at 0x26CC70A55E0>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (321, 640, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (321, 640, 3)

# %%
# R G B

plt.imshow(pic_red[:,:,0])

# %%
# RED CHANNELS VALUES 0-255
# 0 = NO COLOR VALUES
# 255 = FULL COLOR

#plt.imshow(pic_red[:,:,0],cmap='gray') #cmap = color mapping

# %%
plt.imshow(pic_red[:,:,1],cmap='gray') # GREEN

# %%
plt.imshow(pic_red[:,:,2],cmap='gray') # BLUE

# %%
pic_red[:,:,1] = 0
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,1].shape
# Out:
# (321, 640)
